# %%
# @title Install Dependencies
# %%capture
# !pip install git+https://github.com/huggingface/transformers
# !pip install transformers
# !pip install pyctcdecode
# !pip install https://github.com/kpu/kenlm/archive/master.zip
# !pip install accelerate
# !pip install datasets
# !pip install pyannote.audio

# %%
import os
import glob
import pandas as pd

import torch
import librosa

from transformers import Wav2Vec2CTCTokenizer, Wav2Vec2ForCTC, Wav2Vec2Processor
from transformers import AutoProcessor, AutoModelForCTC, AutoFeatureExtractor
from transformers import Wav2Vec2ProcessorWithLM, pipeline

from datasets import load_dataset, Audio, Dataset

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
huggingface_dir = os.path.expanduser("~/.huggingface/")
os.makedirs(huggingface_dir, exist_ok=True)

token_path = os.path.join(huggingface_dir, "token")
with open(token_path, "w") as f:
    f.write("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")

# %% [markdown]
# # **With Adapters**

# %%
import time
def transcribe_audio(input_file,
                     target_lang,
                     device,
                     model_id="Sunbird/sunbird-mms",
                     chunk_length_s=10,
                     stride_length_s=(4, 2),
                     return_timestamps="word"):
    """
    Transcribes audio from the input file using sunbird asr model.

    Args:
        input_file (str): Path to the audio file for transcription.
        target_lang (str): Target language for transcription.
            'ach' - Acholi
            'lug' - Luganda
            'teo' - Ateso
            'lgg' - Lugbara
        device (str or torch.device): Device for running the model (e.g., 'cpu', 'cuda').
        model_id (str, optional): ID of the asr model. Defaults to "Sunbird/sunbird-mms".
        chunk_length_s (int, optional): Length of audio chunks in seconds. Defaults to 5.

    Returns:
        dict: A dictionary containing the transcription result.
            Example: {'text': 'Transcribed text here.'}
    """


    pipe = pipeline(model=model_id, device=device)
    pipe.tokenizer.set_target_lang(target_lang)
    pipe.model.load_adapter(target_lang)

    output = pipe(input_file, chunk_length_s=chunk_length_s, stride_length_s=stride_length_s,return_timestamps="word")
    return output

# %%
input_file_path = "/content/poll9_30_sec.wav"
target_language = "lug"
transcription_result = transcribe_audio(input_file_path, target_language, device)
transcription_result
# Out:
# Some weights of the model checkpoint at Sunbird/sunbird-mms were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at Sunbird/sunbird-mms and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# {'text': 'a kukaako ane amanya neddoboozi gimi ya musasenkanga nga nze kyapesoni wa disitulict mumens cansel e ruweero zisanyisa okulaba mu kyala gimeya webale kugamikwano gyaffe abatruk effe mbagenda maaso nokunoonyereza ku zimu ku nsonga ezikosa obulamu bwaffe ebyenfuna baffe nebirala ebisinga kw ebyo omulungi ogwo tubadde nekibuuzo ekibadde kitambula ngekibuuzo kiri nti twagala okumanya eyo mu kitundu kyo kiki kyolowooza ekivuddeko abaana bano abali wakati wemyaka kumi esatu ne kumi emwenda okufuna embuto ensonga ezo ziruddemu nnyo ate era ozitegeerera ddala bulungi nnyo nkakasa bwe tutandika okwogera ku baana okufuna embuto mu kitundu kyo gwe nga akola ku nsonga zabakyala oteeka okuba nga ozirabye oziwulidde ozikozeeko awuliriza yali agadde okumanyaa nga bwe mbagambye envudde luweero era omulama gwe tulina olwaleeroyinza okuba sikinnyonnyola bulungi ngomukugueeza omwana atanetuuka nolubutoemyaka gye tusinze okulaba okuviira ddala ku myaka ogambye kumi nesatukmeskdnabakkumi nogumu kkumi nebiri nga kisinziira ng ol aandise okulaba omusana noze okitegeera ekyo aba atandise ugenda mu menstral periodsun kati omwana bwe abatandisi ogugenda mu nsonga mulimu abagendamu mangu myaka mwenda myaka kkumi kkumi nagumu ngati weyegata nomulenzi kuba nomusajja kiba kitegeeza abaalina okufuna olubuto kati eieyokuva kumi nesatu paaka kumi na menda ddala kituufu abaana ensangi zino bazaddenyo',
#  'chunks': [{'text': 'a', 'timestamp': (1.08, 1.1)},
#   {'text': 'kukaako', 'timestamp': (1.5, 2.14)},
#   {'text': 'ane', 'timestamp': (2.28, 2.8)},
#   {'text': 'amanya', 'timestamp': (4.18, 4.46)},
#   {'text': 'neddoboozi', 'timestamp': (4.54, 5.22)},
#   {'text': 'gimi', 'timestamp': (6.32, 6.58)},
#   {'text': 'ya', 'timestamp': (6.62, 6.68)},
#   {'text': 'musasenkanga', 'timestamp': (6.76, 7.68)},
#   {'text': 'nga', 'timestamp': (8.36, 8.48)},
#   {'text': 'nze', 'timestamp': (8.58, 8.78)},
#   {'text': 'kyapesoni', 'timestamp': (9.02, 9.7)},
#   {'text': 'wa', 'timestamp': (9.76, 9.84)},
#   {'text': 'disitulict', 'timestamp': (9.92, 10.32)},
#   {'text': 'mumens', 'timestamp': (10.46, 10.96)},
#   {'text': 'cansel', 'timestamp': (11.08, 11.58)},
#   {'text': 'e', 'timestamp': (11.74, 11.76)},
#   {'text': 'ruweero', 'timestamp': (11.82, 12.32)},
#   {'text': 'zisanyisa', 'timestamp': (13.3, 13.7)},
#   {'text': 'okulaba', 'timestamp': (13.76, 14.12)},
#   {'text': 'mu', 'timestamp': (14.34, 14.44)},
#   {'text': 'kyala', 'timestamp': (14.52, 14.78)},
#   {'text': 'gimeya', 'timestamp': (14.92, 15.28)},
#   {'text': 'webale', 'timestamp': (17.34, 17.64)},
#   {'text': 'kugamikwano', 'timestamp': (17.72, 21.74)},
#   {'text': 'gyaffe', 'timestamp': (21.78, 21.98)},
#   {'text': 'abatruk', 'timestamp': (22.02, 22.36)},
#   {'text': 'effe', 'timestamp': (22.46, 22.64)},
#   {'text': 'mbagenda', 'timestamp': (22.7, 23.02)},
#   {'text': 'maaso', 'timestamp': (23.08, 23.26)},
#   {'text': 'nokunoonyereza', 'timestamp': (23.34, 23.98)},
#   {'text': 'ku', 'timestamp': (24.38, 24.46)},
#   {'text': 'zimu', 'timestamp': (24.54, 24.76)},
#   {'text': 'ku', 'timestamp': (24.82, 24.9)},
#   {'text': 'nsonga', 'timestamp': (24.98, 25.4)},
#   {'text': 'ezikosa', 'timestamp': (25.56, 26.02)},
#   {'text': 'obulamu', 'timestamp': (26.46, 26.74)},
#   {'text': 'bwaffe', 'timestamp': (26.8, 27.08)},
#   {'text': 'ebyenfuna', 'timestamp': (27.26, 27.64)},
#   {'text': 'baffe', 'timestamp': (27.72, 27.9)},
#   {'text': 'nebirala', 'timestamp': (27.96, 28.24)},
#   {'text': 'ebisinga', 'timestamp': (28.28, 28.64)},
#   {'text': 'kw', 'timestamp': (28.74, 28.82)},
#   {'text': 'ebyo', 'timestamp': (28.88, 29.08)},
#   {'text': 'omulungi', 'timestamp': (29.44, 29.72)},
#   {'text': 'ogwo', 'timestamp': (29.78, 29.88)},
#   {'text': 'tubadde', 'timestamp': (29.94, 30.22)},
#   {'text': 'nekibuuzo', 'timestamp': (30.3, 30.8)},
#   {'text': 'ekibadde', 'timestamp': (30.86, 31.16)},
#   {'text': 'kitambula', 'timestamp': (31.24, 31.66)},
#   {'text': 'ngekibuuzo', 'timestamp': (34.06, 34.54)},
#   {'text': 'kiri', 'timestamp': (34.62, 34.82)},
#   {'text': 'nti', 'timestamp': (34.92, 35.08)},
#   {'text': 'twagala', 'timestamp': (36.56, 36.94)},
#   {'text': 'okumanya', 'timestamp': (36.98, 37.36)},
#   {'text': 'eyo', 'timestamp': (37.6, 37.72)},
#   {'text': 'mu', 'timestamp': (37.78, 37.84)},
#   {'text': 'kitundu', 'timestamp': (37.88, 38.26)},
#   {'text': 'kyo', 'timestamp': (38.32, 38.44)},
#   {'text': 'kiki', 'timestamp': (38.6, 38.84)},
#   {'text': 'kyolowooza', 'timestamp': (38.88, 39.38)},
#   {'text': 'ekivuddeko', 'timestamp': (39.44, 39.9)},
#   {'text': 'abaana', 'timestamp': (39.98, 40.24)},
#   {'text': 'bano', 'timestamp': (40.3, 40.44)},
#   {'text': 'abali', 'timestamp': (40.48, 40.64)},
#   {'text': 'wakati', 'timestamp': (40.68, 40.92)},
#   {'text': 'wemyaka', 'timestamp': (40.98, 41.26)},
#   {'text': 'kumi', 'timestamp': (41.96, 42.1)},
#   {'text': 'esatu', 'timestamp': (42.18, 42.5)},
#   {'text': 'ne', 'timestamp': (42.92, 42.98)},
#   {'text': 'kumi', 'timestamp': (43.06, 43.2)},
#   {'text': 'emwenda', 'timestamp': (43.32, 43.74)},
#   {'text': 'okufuna', 'timestamp': (44.16, 44.5)},
#   {'text': 'embuto', 'timestamp': (44.74, 45.12)},
#   {'text': 'ensonga', 'timestamp': (46.08, 46.58)},
#   {'text': 'ezo', 'timestamp': (46.66, 46.82)},
#   {'text': 'ziruddemu', 'timestamp': (46.92, 47.42)},
#   {'text': 'nnyo', 'timestamp': (47.46, 47.62)},
#   {'text': 'ate', 'timestamp': (47.8, 47.98)},
#   {'text': 'era', 'timestamp': (48.06, 48.14)},
#   {'text': 'ozitegeerera', 'timestamp': (48.32, 48.9)},
#   {'text': 'ddala', 'timestamp': (48.94, 49.14)},
#   {'text': 'bulungi', 'timestamp': (49.2, 49.56)},
#   {'text': 'nnyo', 'timestamp': (49.62, 49.8)},
#   {'text': 'nkakasa', 'timestamp': (50.94, 51.28)},
#   {'text': 'bwe', 'timestamp': (51.34, 51.42)},
#   {'text': 'tutandika', 'timestamp': (51.46, 51.96)},
#   {'text': 'okwogera', 'timestamp': (52.16, 52.52)},
#   {'text': 'ku', 'timestamp': (52.6, 52.66)},
#   {'text': 'baana', 'timestamp': (52.68, 52.88)},
#   {'text': 'okufuna', 'timestamp': (52.92, 53.16)},
#   {'text': 'embuto', 'timestamp': (53.22, 53.48)},
#   {'text': 'mu', 'timestamp': (53.92, 54.0)},
#   {'text': 'kitundu', 'timestamp': (54.04, 54.46)},
#   {'text': 'kyo', 'timestamp': (54.52, 54.64)},
#   {'text': 'gwe', 'timestamp': (55.14, 55.26)},
#   {'text': 'nga', 'timestamp': (55.5, 55.64)},
#   {'text': 'akola', 'timestamp': (55.74, 55.94)},
#   {'text': 'ku', 'timestamp': (56.0, 56.06)},
#   {'text': 'nsonga', 'timestamp': (56.14, 56.4)},
#   {'text': 'zabakyala', 'timestamp': (56.5, 57.12)},
#   {'text': 'oteeka', 'timestamp': (57.6, 57.88)},
#   {'text': 'okuba', 'timestamp': (58.1, 58.34)},
#   {'text': 'nga', 'timestamp': (58.44, 58.54)},
#   {'text': 'ozirabye', 'timestamp': (58.98, 59.56)},
#   {'text': 'oziwulidde', 'timestamp': (59.86, 60.6)},
#   {'text': 'ozikozeeko', 'timestamp': (61.04, 61.96)},
#   {'text': 'awuliriza', 'timestamp': (62.78, 63.2)},
#   {'text': 'yali', 'timestamp': (63.28, 63.44)},
#   {'text': 'agadde', 'timestamp': (63.52, 63.8)},
#   {'text': 'okumanyaa', 'timestamp': (63.88, 68.04)},
#   {'text': 'nga', 'timestamp': (68.94, 69.06)},
#   {'text': 'bwe', 'timestamp': (69.1, 69.2)},
#   {'text': 'mbagambye', 'timestamp': (69.24, 69.74)},
#   {'text': 'envudde', 'timestamp': (69.8, 70.16)},
#   {'text': 'luweero', 'timestamp': (70.28, 70.76)},
#   {'text': 'era', 'timestamp': (71.92, 72.08)},
#   {'text': 'omulama', 'timestamp': (72.84, 73.16)},
#   {'text': 'gwe', 'timestamp': (73.24, 73.34)},
#   {'text': 'tulina', 'timestamp': (73.42, 73.74)},
#   {'text': 'olwaleeroyinza', 'timestamp': (73.82, 78.78)},
#   {'text': 'okuba', 'timestamp': (78.82, 78.96)},
#   {'text': 'sikinnyonnyola', 'timestamp': (79.04, 79.66)},
#   {'text': 'bulungi', 'timestamp': (79.72, 80.02)},
#   {'text': 'ngomukugueeza', 'timestamp': (80.08, 84.34)},
#   {'text': 'omwana', 'timestamp': (85.12, 85.56)},
#   {'text': 'atanetuuka', 'timestamp': (85.86, 86.9)},
#   {'text': 'nolubutoemyaka', 'timestamp': (87.58, 90.1)},
#   {'text': 'gye', 'timestamp': (90.18, 90.26)},
#   {'text': 'tusinze', 'timestamp': (90.32, 90.64)},
#   {'text': 'okulaba', 'timestamp': (90.72, 91.04)},
#   {'text': 'okuviira', 'timestamp': (91.28, 91.62)},
#   {'text': 'ddala', 'timestamp': (91.66, 91.84)},
#   {'text': 'ku', 'timestamp': (91.92, 92.0)},
#   {'text': 'myaka', 'timestamp': (92.08, 92.46)},
#   {'text': 'ogambye', 'timestamp': (93.16, 93.48)},
#   {'text': 'kumi', 'timestamp': (93.56, 93.7)},
#   {'text': 'nesatukmeskdnabakkumi', 'timestamp': (93.78, 96.9)},
#   {'text': 'nogumu', 'timestamp': (97.0, 97.52)},
#   {'text': 'kkumi', 'timestamp': (97.56, 97.78)},
#   {'text': 'nebiri', 'timestamp': (97.86, 98.3)},
#   {'text': 'nga', 'timestamp': (98.72, 98.8)},
#   {'text': 'kisinziira', 'timestamp': (98.88, 99.7)},
#   {'text': 'ng', 'timestamp': (100.66, 100.72)},
#   {'text': 'ol', 'timestamp': (100.8, 100.86)},
#   {'text': 'aandise', 'timestamp': (100.94, 101.34)},
#   {'text': 'okulaba', 'timestamp': (101.4, 101.72)},
#   {'text': 'omusana', 'timestamp': (101.78, 102.24)},
#   {'text': 'noze', 'timestamp': (102.86, 103.1)},
#   {'text': 'okitegeera', 'timestamp': (103.16, 103.74)},
#   {'text': 'ekyo', 'timestamp': (103.84, 104.02)},
#   {'text': 'aba', 'timestamp': (104.5, 104.6)},
#   {'text': 'atandise', 'timestamp': (104.66, 104.98)},
#   {'text': 'ugenda', 'timestamp': (105.08, 105.3)},
#   {'text': 'mu', 'timestamp': (105.36, 105.42)},
#   {'text': 'menstral', 'timestamp': (105.46, 105.86)},
#   {'text': 'periodsun', 'timestamp': (105.92, 108.48)},
#   {'text': 'kati', 'timestamp': (109.36, 109.52)},
#   {'text': 'omwana', 'timestamp': (109.58, 109.84)},
#   {'text': 'bwe', 'timestamp': (109.88, 109.96)},
#   {'text': 'abatandisi', 'timestamp': (110.02, 110.46)},
#   {'text': 'ogugenda', 'timestamp': (110.5, 110.76)},
#   {'text': 'mu', 'timestamp': (110.84, 110.9)},
#   {'text': 'nsonga', 'timestamp': (110.98, 111.36)},
#   {'text': 'mulimu', 'timestamp': (111.56, 111.96)},
#   {'text': 'abagendamu', 'timestamp': (112.28, 113.02)},
#   {'text': 'mangu', 'timestamp': (113.1, 113.5)},
#   {'text': 'myaka', 'timestamp': (113.9, 114.22)},
#   {'text': 'mwenda', 'timestamp': (114.34, 114.74)},
#   {'text': 'myaka', 'timestamp': (114.86, 115.14)},
#   {'text': 'kkumi', 'timestamp': (115.24, 115.54)},
#   {'text': 'kkumi', 'timestamp': (115.62, 115.82)},
#   {'text': 'nagumu', 'timestamp': (115.9, 116.28)},
#   {'text': 'ngati', 'timestamp': (116.62, 116.82)},
#   {'text': 'weyegata', 'timestamp': (116.88, 117.44)},
#   {'text': 'nomulenzi', 'timestamp': (117.54, 118.24)},
#   {'text': 'kuba', 'timestamp': (118.62, 118.74)},
#   {'text': 'nomusajja', 'timestamp': (118.82, 119.44)},
#   {'text': 'kiba', 'timestamp': (120.18, 120.36)},
#   {'text': 'kitegeeza', 'timestamp': (120.42, 120.86)},
#   {'text': 'abaalina', 'timestamp': (120.94, 121.24)},
#   {'text': 'okufuna', 'timestamp': (121.3, 121.6)},
#   {'text': 'olubuto', 'timestamp': (121.68, 122.04)},
#   {'text': 'kati', 'timestamp': (122.46, 122.74)},
#   {'text': 'eieyokuva', 'timestamp': (123.58, 125.16)},
#   {'text': 'kumi', 'timestamp': (125.32, 125.52)},
#   {'text': 'nesatu', 'timestamp': (125.6, 126.1)},
#   {'text': 'paaka', 'timestamp': (126.18, 126.36)},
#   {'text': 'kumi', 'timestamp': (126.44, 126.6)},
#   {'text': 'na', 'timestamp': (126.66, 126.72)},
#   {'text': 'menda', 'timestamp': (126.8, 127.14)},
#   {'text': 'ddala', 'timestamp': (127.66, 127.88)},
#   {'text': 'kituufu', 'timestamp': (127.96, 128.58)},
#   {'text': 'abaana', 'timestamp': (129.02, 129.48)},
#   {'text': 'ensangi', 'timestamp': (129.56, 129.96)},
#   {'text': 'zino', 'timestamp': (130.06, 130.26)},
#   {'text': 'bazaddenyo', 'timestamp': (130.34, 131.02)}]}

# %% [markdown]
# # **Diarization**

# %%
import numpy as np
import pandas as pd
from pyannote.audio import Pipeline
from typing import Optional, Union
import torch
import numpy as np

# from .audio import load_audio, SAMPLE_RATE
# Out:
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/torch_audiomentations/utils/io.py:27: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")

# %%
device
# Out:
# device(type='cuda')

# %%
SAMPLE_RATE = 16000

def load_audio(file: str, sr: int = SAMPLE_RATE) -> np.ndarray:
    """
    Open an audio file and read as mono waveform, resampling as necessary.

    Parameters
    ----------
    file: str
        The audio file to open

    sr: int
        The sample rate to resample the audio if necessary

    Returns
    -------
    A NumPy array containing the audio waveform, in float32 dtype.
    """
    try:
        # librosa automatically resamples to the given sample rate (if necessary)
        # and converts the signal to mono (by averaging channels)
        audio, _ = librosa.load(file, sr=sr, mono=True, dtype=np.float32)
    except Exception as e:
        raise RuntimeError(f"Failed to load audio with librosa: {e}") from e

    return audio

# %%
class DiarizationPipeline:
    """
    A pipeline for performing speaker diarization on audio data.

    This class initializes with a pretrained diarization model and can be called
    with an audio file or waveform to perform diarization, returning a DataFrame
    with the start and end times for each speaker segment.

    Attributes:
        model (Pipeline): The loaded diarization model ready for inference.
    """

    def __init__(
        self,
        model_name="pyannote/speaker-diarization-3.0",
        use_auth_token=None,
        device: Optional[Union[str, torch.device]] = "cpu",
    ):
        """
        Initializes the DiarizationPipeline with a pretrained model.

        Args:
            model_name (str): The name of the pretrained diarization model to load.
            use_auth_token (str, optional): Token to use for authentication if the model
                                            is from a private repository. Defaults to None.
            device (str or torch.device, optional): The device on which to run the model,
                                                    either "cpu" or "cuda". Defaults to "cpu".
        """
        if isinstance(device, str):
            device = torch.device(device)
        self.model = Pipeline.from_pretrained(model_name, use_auth_token=use_auth_token).to(device)

    def __call__(
        self,
        audio: Union[str, np.ndarray],
        min_speakers: Optional[int] = None,
        max_speakers: Optional[int] = None
    ) -> pd.DataFrame:
        """
        Perform diarization on the provided audio.

        Args:
            audio (str or np.ndarray): The path to the audio file or a numpy array of the waveform.
            min_speakers (int, optional): The minimum number of speakers to assume in the diarization
                                          process. Defaults to None.
            max_speakers (int, optional): The maximum number of speakers to assume in the diarization
                                          process. Defaults to None.

        Returns:
            DataFrame: A pandas DataFrame with columns for the segment, label, speaker,
                       start time, and end time of each speaker segment.
        """
        if isinstance(audio, str):
            audio = load_audio(audio)
        audio_data = {
            'waveform': torch.from_numpy(audio[None, :]),
            'sample_rate': SAMPLE_RATE
        }
        segments = self.model(audio_data, min_speakers=min_speakers, max_speakers=max_speakers)
        diarize_df = pd.DataFrame(segments.itertracks(yield_label=True), columns=['segment', 'label', 'speaker'])
        diarize_df['start'] = diarize_df['segment'].apply(lambda x: x.start)
        diarize_df['end'] = diarize_df['segment'].apply(lambda x: x.end)
        return diarize_df

# %%
def assign_word_speakers(diarize_df, transcript_result, fill_nearest=False):
    """
    Assign speakers to segments of a transcript based on the results of a diarization data frame.

    This function iterates through segments of a transcript and assigns the speaker labels
    based on the overlap between the speech segments and the diarization data. Optionally,
    if `fill_nearest` is True, the function will assign speakers even to segments that
    do not have a direct overlap with the diarization data by finding the closest speaker
    in time.

    Parameters:
    - diarize_df (DataFrame): A pandas DataFrame containing the diarization information
                              with columns 'start', 'end', and 'speaker'.
    - transcript_result (dict): A dictionary with a key 'chunks' that contains a list of
                                transcript segments, where each segment is a dictionary
                                with keys 'text' and 'timestamp' (a tuple with start and end times).
    - fill_nearest (bool, optional): A flag to determine whether to assign speakers to all segments
                                     based on the nearest speaker data if no direct overlap is found.
                                     Defaults to False.

    Returns:
    - dict: The updated transcript_result with speakers assigned to each segment.

    Examples of diarize_df and transcript_result structures:

    diarize_df example:
        speaker  start   end
        0        0.0     1.5
        1        1.5     3.0

    transcript_result example:
        {'chunks': [{'text': 'Hello', 'timestamp': (0.5, 1.0)},
                    {'text': 'world', 'timestamp': (1.5, 2.0)}]}

    Example usage:
    >>> diarize_df = pd.DataFrame({'speaker': [0, 1], 'start': [0.0, 1.5], 'end': [1.5, 3.0]})
    >>> transcript_result = {'chunks': [{'text': 'Hello', 'timestamp': (0.5, 1.0)},
                                         {'text': 'world', 'timestamp': (1.5, 2.0)}]}
    >>> assign_word_speakers(diarize_df, transcript_result)
    {'chunks': [{'text': 'Hello', 'timestamp': (0.5, 1.0), 'speaker': 0},
                {'text': 'world', 'timestamp': (1.5, 2.0), 'speaker': 1}]}
    """
    transcript_segments = transcript_result["chunks"]

    for seg in transcript_segments:
        # Calculate intersection and union between diarization segments and transcript segment
        diarize_df['intersection'] = np.minimum(diarize_df['end'], seg["timestamp"][1]) - np.maximum(diarize_df['start'], seg["timestamp"][0])
        diarize_df['union'] = np.maximum(diarize_df['end'], seg["timestamp"][1]) - np.minimum(diarize_df['start'], seg["timestamp"][0])

        # Filter out diarization segments with no overlap if fill_nearest is False
        if not fill_nearest:
            dia_tmp = diarize_df[diarize_df['intersection'] > 0]
        else:
            dia_tmp = diarize_df

        # If there are overlapping segments, assign the speaker with the greatest overlap
        if len(dia_tmp) > 0:
            speaker = dia_tmp.groupby("speaker")["intersection"].sum().sort_values(ascending=False).index[0]
            seg["speaker"] = speaker

    return transcript_result

# %%
class Segment:
    """
    A class to represent a single segment of audio with a start time, end time, and speaker label.

    This class is typically used to encapsulate the information about a segment of audio that
    has been identified during a speaker diarization process, including the time the segment
    starts, when it ends, and which speaker is speaking.

    Attributes:
        start (float): The start time of the audio segment in seconds.
        end (float): The end time of the audio segment in seconds.
        speaker (str, optional): The label of the speaker for this audio segment. Defaults to None.
    """

    def __init__(self, start, end, speaker=None):
        """
        Initializes a new instance of the Segment class.

        Args:
            start (float): The start time of the audio segment in seconds.
            end (float): The end time of the audio segment in seconds.
            speaker (str, optional): The label of the speaker for this segment. If not specified,
                                     the speaker attribute is set to None.
        """
        self.start = start
        self.end = end
        self.speaker = speaker

# %%
transcription_result
results = []
tmp_results = transcription_result
hf_token="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"
diarize_model = DiarizationPipeline(use_auth_token=hf_token, device=device)

# %%
transcription_result["text"]
# Out:
# 'a kukaako ane amanya neddoboozi gimi ya musasenkanga nga nze kyapesoni wa disitulict mumens cansel e ruweero zisanyisa okulaba mu kyala gimeya webale kugamikwano gyaffe abatruk effe mbagenda maaso nokunoonyereza ku zimu ku nsonga ezikosa obulamu bwaffe ebyenfuna baffe nebirala ebisinga kw ebyo omulungi ogwo tubadde nekibuuzo ekibadde kitambula ngekibuuzo kiri nti twagala okumanya eyo mu kitundu kyo kiki kyolowooza ekivuddeko abaana bano abali wakati wemyaka kumi esatu ne kumi emwenda okufuna embuto ensonga ezo ziruddemu nnyo ate era ozitegeerera ddala bulungi nnyo nkakasa bwe tutandika okwogera ku baana okufuna embuto mu kitundu kyo gwe nga akola ku nsonga zabakyala oteeka okuba nga ozirabye oziwulidde ozikozeeko awuliriza yali agadde okumanyaa nga bwe mbagambye envudde luweero era omulama gwe tulina olwaleeroyinza okuba sikinnyonnyola bulungi ngomukugueeza omwana atanetuuka nolubutoemyaka gye tusinze okulaba okuviira ddala ku myaka ogambye kumi nesatukmeskdnabakkumi nogumu kkumi nebiri nga kisinziira ng ol aandise okulaba omusana noze okitegeera ekyo aba atandise ugenda mu menstral periodsun kati omwana bwe abatandisi ogugenda mu nsonga mulimu abagendamu mangu myaka mwenda myaka kkumi kkumi nagumu ngati weyegata nomulenzi kuba nomusajja kiba kitegeeza abaalina okufuna olubuto kati eieyokuva kumi nesatu paaka kumi na menda ddala kituufu abaana ensangi zino bazaddenyo'

# %%
diarize_segments = diarize_model("/content/poll9_30_sec.wav", min_speakers=None, max_speakers=None)

# %%
diarize_segments
# Out:
#                               segment  label     speaker       start  \
# 0   [ 00:00:00.008 -->  00:00:05.441]      1  SPEAKER_01    0.008489
# 1   [ 00:00:00.534 -->  00:00:01.146]      0  SPEAKER_00    0.534805
# 2   [ 00:00:02.758 -->  00:00:03.132]      0  SPEAKER_00    2.758913
# 3   [ 00:00:03.641 -->  00:00:03.794]      0  SPEAKER_00    3.641766
# 4   [ 00:00:03.930 -->  00:00:03.998]      0  SPEAKER_00    3.930390
# 5   [ 00:00:05.882 -->  00:00:07.886]      1  SPEAKER_01    5.882852
# 6   [ 00:00:08.327 -->  00:00:12.470]      1  SPEAKER_01    8.327674
# 7   [ 00:00:13.132 -->  00:00:16.290]      0  SPEAKER_00   13.132428
# 8   [ 00:00:16.663 -->  00:00:19.142]      0  SPEAKER_00   16.663837
# 9   [ 00:00:19.601 -->  00:00:35.271]      0  SPEAKER_00   19.601019
# 10  [ 00:00:36.477 -->  00:00:45.390]      0  SPEAKER_00   36.477080
# 11  [ 00:00:45.933 -->  00:00:50.008]      0  SPEAKER_00   45.933786
# 12  [ 00:00:50.857 -->  00:01:02.249]      0  SPEAKER_00   50.857385
# 13  [ 00:01:02.623 -->  00:01:04.490]      0  SPEAKER_00   62.623090
# 14  [ 00:01:04.694 -->  00:01:05.237]      1  SPEAKER_01   64.694397
# 15  [ 00:01:05.220 -->  00:01:05.696]      0  SPEAKER_00   65.220713
# 16  [ 00:01:06.443 -->  00:01:08.259]      1  SPEAKER_01   66.443124
# 17  [ 00:01:08.820 -->  00:01:10.874]      1  SPEAKER_01   68.820034
# 18  [ 00:01:10.925 -->  00:01:11.332]      0  SPEAKER_00   70.925297
# 19  [ 00:01:11.825 -->  00:01:17.173]      1  SPEAKER_01   71.825127
# 20  [ 00:01:17.173 -->  00:01:20.840]      0  SPEAKER_00   77.173175
# 21  [ 00:01:21.383 -->  00:01:21.468]      1  SPEAKER_01   81.383701
# 22  [ 00:01:21.468 -->  00:01:22.028]      0  SPEAKER_00   81.468591
# 23  [ 00:01:21.485 -->  00:01:21.502]      1  SPEAKER_01   81.485569
# 24  [ 00:01:21.570 -->  00:01:21.977]      1  SPEAKER_01   81.570458
# 25  [ 00:01:22.164 -->  00:01:24.473]      1  SPEAKER_01   82.164686
# 26  [ 00:01:25.016 -->  00:01:28.344]      1  SPEAKER_01   85.016978
# 27  [ 00:01:27.139 -->  00:01:27.818]      0  SPEAKER_00   87.139219
# 28  [ 00:01:28.344 -->  00:01:28.786]      0  SPEAKER_00   88.344652
# 29  [ 00:01:28.786 -->  00:01:32.640]      1  SPEAKER_01   88.786078
# 30  [ 00:01:33.064 -->  00:01:34.456]      1  SPEAKER_01   93.064516
# 31  [ 00:01:34.456 -->  00:01:36.290]      0  SPEAKER_00   94.456706
# 32  [ 00:01:35.000 -->  00:01:44.083]      1  SPEAKER_01   95.000000
# 33  [ 00:01:40.178 -->  00:01:40.297]      0  SPEAKER_00  100.178268
# 34  [ 00:01:44.354 -->  00:01:47.190]      1  SPEAKER_01  104.354839
# 35  [ 00:01:46.307 -->  00:01:47.988]      0  SPEAKER_00  106.307301
# 36  [ 00:01:47.988 -->  00:01:59.617]      1  SPEAKER_01  107.988115
# 37  [ 00:01:49.278 -->  00:01:49.414]      0  SPEAKER_00  109.278438
# 38  [ 00:01:56.511 -->  00:01:57.207]      0  SPEAKER_00  116.511036
# 39  [ 00:01:58.463 -->  00:01:58.938]      0  SPEAKER_00  118.463497
# 40  [ 00:02:00.144 -->  00:02:11.196]      1  SPEAKER_01  120.144312
# 41  [ 00:02:02.164 -->  00:02:02.945]      0  SPEAKER_00  122.164686
#
#            end
# 0     5.441426
# 1     1.146010
# 2     3.132428
# 3     3.794567
# 4     3.998302
# 5     7.886248
# 6    12.470289
# 7    16.290323
# 8    19.142615
# 9    35.271647
# 10   45.390492
# 11   50.008489
# 12   62.249576
# 13   64.490662
# 14   65.237691
# 15   65.696095
# 16   68.259762
# 17   70.874363
# 18   71.332767
# 19   77.173175
# 20   80.840407
# 21   81.468591
# 22   82.028862
# 23   81.502547
# 24   81.977929
# 25   84.473684
# 26   88.344652
# 27   87.818336
# 28   88.786078
# 29   92.640068
# 30   94.456706
# 31   96.290323
# 32  104.083192
# 33  100.297114
# 34  107.190153
# 35  107.988115
# 36  119.617997
# 37  109.414261
# 38  117.207131
# 39  118.938879
# 40  131.196944
# 41  122.945671

# %%
output = assign_word_speakers(diarize_segments, transcription_result)

# %%
output
# Out:
# {'text': 'a kukaako ane amanya neddoboozi gimi ya musasenkanga nga nze kyapesoni wa disitulict mumens cansel e ruweero zisanyisa okulaba mu kyala gimeya webale kugamikwano gyaffe abatruk effe mbagenda maaso nokunoonyereza ku zimu ku nsonga ezikosa obulamu bwaffe ebyenfuna baffe nebirala ebisinga kw ebyo omulungi ogwo tubadde nekibuuzo ekibadde kitambula ngekibuuzo kiri nti twagala okumanya eyo mu kitundu kyo kiki kyolowooza ekivuddeko abaana bano abali wakati wemyaka kumi esatu ne kumi emwenda okufuna embuto ensonga ezo ziruddemu nnyo ate era ozitegeerera ddala bulungi nnyo nkakasa bwe tutandika okwogera ku baana okufuna embuto mu kitundu kyo gwe nga akola ku nsonga zabakyala oteeka okuba nga ozirabye oziwulidde ozikozeeko awuliriza yali agadde okumanyaa nga bwe mbagambye envudde luweero era omulama gwe tulina olwaleeroyinza okuba sikinnyonnyola bulungi ngomukugueeza omwana atanetuuka nolubutoemyaka gye tusinze okulaba okuviira ddala ku myaka ogambye kumi nesatukmeskdnabakkumi nogumu kkumi nebiri nga kisinziira ng ol aandise okulaba omusana noze okitegeera ekyo aba atandise ugenda mu menstral periodsun kati omwana bwe abatandisi ogugenda mu nsonga mulimu abagendamu mangu myaka mwenda myaka kkumi kkumi nagumu ngati weyegata nomulenzi kuba nomusajja kiba kitegeeza abaalina okufuna olubuto kati eieyokuva kumi nesatu paaka kumi na menda ddala kituufu abaana ensangi zino bazaddenyo',
#  'chunks': [{'text': 'a', 'timestamp': (1.08, 1.1), 'speaker': 'SPEAKER_00'},
#   {'text': 'kukaako', 'timestamp': (1.5, 2.14), 'speaker': 'SPEAKER_01'},
#   {'text': 'ane', 'timestamp': (2.28, 2.8), 'speaker': 'SPEAKER_01'},
#   {'text': 'amanya', 'timestamp': (4.18, 4.46), 'speaker': 'SPEAKER_01'},
#   {'text': 'neddoboozi', 'timestamp': (4.54, 5.22), 'speaker': 'SPEAKER_01'},
#   {'text': 'gimi', 'timestamp': (6.32, 6.58), 'speaker': 'SPEAKER_01'},
#   {'text': 'ya', 'timestamp': (6.62, 6.68), 'speaker': 'SPEAKER_01'},
#   {'text': 'musasenkanga', 'timestamp': (6.76, 7.68), 'speaker': 'SPEAKER_01'},
#   {'text': 'nga', 'timestamp': (8.36, 8.48), 'speaker': 'SPEAKER_01'},
#   {'text': 'nze', 'timestamp': (8.58, 8.78), 'speaker': 'SPEAKER_01'},
#   {'text': 'kyapesoni', 'timestamp': (9.02, 9.7), 'speaker': 'SPEAKER_01'},
#   {'text': 'wa', 'timestamp': (9.76, 9.84), 'speaker': 'SPEAKER_01'},
#   {'text': 'disitulict', 'timestamp': (9.92, 10.32), 'speaker': 'SPEAKER_01'},
#   {'text': 'mumens', 'timestamp': (10.46, 10.96), 'speaker': 'SPEAKER_01'},
#   {'text': 'cansel', 'timestamp': (11.08, 11.58), 'speaker': 'SPEAKER_01'},
#   {'text': 'e', 'timestamp': (11.74, 11.76), 'speaker': 'SPEAKER_01'},
#   {'text': 'ruweero', 'timestamp': (11.82, 12.32), 'speaker': 'SPEAKER_01'},
#   {'text': 'zisanyisa', 'timestamp': (13.3, 13.7), 'speaker': 'SPEAKER_00'},
#   {'text': 'okulaba', 'timestamp': (13.76, 14.12), 'speaker': 'SPEAKER_00'},
#   {'text': 'mu', 'timestamp': (14.34, 14.44), 'speaker': 'SPEAKER_00'},
#   {'text': 'kyala', 'timestamp': (14.52, 14.78), 'speaker': 'SPEAKER_00'},
#   {'text': 'gimeya', 'timestamp': (14.92, 15.28), 'speaker': 'SPEAKER_00'},
#   {'text': 'webale', 'timestamp': (17.34, 17.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'kugamikwano',
#    'timestamp': (17.72, 21.74),
#    'speaker': 'SPEAKER_00'},
#   {'text': 'gyaffe', 'timestamp': (21.78, 21.98), 'speaker': 'SPEAKER_00'},
#   {'text': 'abatruk', 'timestamp': (22.02, 22.36), 'speaker': 'SPEAKER_00'},
#   {'text': 'effe', 'timestamp': (22.46, 22.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'mbagenda', 'timestamp': (22.7, 23.02), 'speaker': 'SPEAKER_00'},
#   {'text': 'maaso', 'timestamp': (23.08, 23.26), 'speaker': 'SPEAKER_00'},
#   {'text': 'nokunoonyereza',
#    'timestamp': (23.34, 23.98),
#    'speaker': 'SPEAKER_00'},
#   {'text': 'ku', 'timestamp': (24.38, 24.46), 'speaker': 'SPEAKER_00'},
#   {'text': 'zimu', 'timestamp': (24.54, 24.76), 'speaker': 'SPEAKER_00'},
#   {'text': 'ku', 'timestamp': (24.82, 24.9), 'speaker': 'SPEAKER_00'},
#   {'text': 'nsonga', 'timestamp': (24.98, 25.4), 'speaker': 'SPEAKER_00'},
#   {'text': 'ezikosa', 'timestamp': (25.56, 26.02), 'speaker': 'SPEAKER_00'},
#   {'text': 'obulamu', 'timestamp': (26.46, 26.74), 'speaker': 'SPEAKER_00'},
#   {'text': 'bwaffe', 'timestamp': (26.8, 27.08), 'speaker': 'SPEAKER_00'},
#   {'text': 'ebyenfuna', 'timestamp': (27.26, 27.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'baffe', 'timestamp': (27.72, 27.9), 'speaker': 'SPEAKER_00'},
#   {'text': 'nebirala', 'timestamp': (27.96, 28.24), 'speaker': 'SPEAKER_00'},
#   {'text': 'ebisinga', 'timestamp': (28.28, 28.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'kw', 'timestamp': (28.74, 28.82), 'speaker': 'SPEAKER_00'},
#   {'text': 'ebyo', 'timestamp': (28.88, 29.08), 'speaker': 'SPEAKER_00'},
#   {'text': 'omulungi', 'timestamp': (29.44, 29.72), 'speaker': 'SPEAKER_00'},
#   {'text': 'ogwo', 'timestamp': (29.78, 29.88), 'speaker': 'SPEAKER_00'},
#   {'text': 'tubadde', 'timestamp': (29.94, 30.22), 'speaker': 'SPEAKER_00'},
#   {'text': 'nekibuuzo', 'timestamp': (30.3, 30.8), 'speaker': 'SPEAKER_00'},
#   {'text': 'ekibadde', 'timestamp': (30.86, 31.16), 'speaker': 'SPEAKER_00'},
#   {'text': 'kitambula', 'timestamp': (31.24, 31.66), 'speaker': 'SPEAKER_00'},
#   {'text': 'ngekibuuzo', 'timestamp': (34.06, 34.54), 'speaker': 'SPEAKER_00'},
#   {'text': 'kiri', 'timestamp': (34.62, 34.82), 'speaker': 'SPEAKER_00'},
#   {'text': 'nti', 'timestamp': (34.92, 35.08), 'speaker': 'SPEAKER_00'},
#   {'text': 'twagala', 'timestamp': (36.56, 36.94), 'speaker': 'SPEAKER_00'},
#   {'text': 'okumanya', 'timestamp': (36.98, 37.36), 'speaker': 'SPEAKER_00'},
#   {'text': 'eyo', 'timestamp': (37.6, 37.72), 'speaker': 'SPEAKER_00'},
#   {'text': 'mu', 'timestamp': (37.78, 37.84), 'speaker': 'SPEAKER_00'},
#   {'text': 'kitundu', 'timestamp': (37.88, 38.26), 'speaker': 'SPEAKER_00'},
#   {'text': 'kyo', 'timestamp': (38.32, 38.44), 'speaker': 'SPEAKER_00'},
#   {'text': 'kiki', 'timestamp': (38.6, 38.84), 'speaker': 'SPEAKER_00'},
#   {'text': 'kyolowooza', 'timestamp': (38.88, 39.38), 'speaker': 'SPEAKER_00'},
#   {'text': 'ekivuddeko', 'timestamp': (39.44, 39.9), 'speaker': 'SPEAKER_00'},
#   {'text': 'abaana', 'timestamp': (39.98, 40.24), 'speaker': 'SPEAKER_00'},
#   {'text': 'bano', 'timestamp': (40.3, 40.44), 'speaker': 'SPEAKER_00'},
#   {'text': 'abali', 'timestamp': (40.48, 40.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'wakati', 'timestamp': (40.68, 40.92), 'speaker': 'SPEAKER_00'},
#   {'text': 'wemyaka', 'timestamp': (40.98, 41.26), 'speaker': 'SPEAKER_00'},
#   {'text': 'kumi', 'timestamp': (41.96, 42.1), 'speaker': 'SPEAKER_00'},
#   {'text': 'esatu', 'timestamp': (42.18, 42.5), 'speaker': 'SPEAKER_00'},
#   {'text': 'ne', 'timestamp': (42.92, 42.98), 'speaker': 'SPEAKER_00'},
#   {'text': 'kumi', 'timestamp': (43.06, 43.2), 'speaker': 'SPEAKER_00'},
#   {'text': 'emwenda', 'timestamp': (43.32, 43.74), 'speaker': 'SPEAKER_00'},
#   {'text': 'okufuna', 'timestamp': (44.16, 44.5), 'speaker': 'SPEAKER_00'},
#   {'text': 'embuto', 'timestamp': (44.74, 45.12), 'speaker': 'SPEAKER_00'},
#   {'text': 'ensonga', 'timestamp': (46.08, 46.58), 'speaker': 'SPEAKER_00'},
#   {'text': 'ezo', 'timestamp': (46.66, 46.82), 'speaker': 'SPEAKER_00'},
#   {'text': 'ziruddemu', 'timestamp': (46.92, 47.42), 'speaker': 'SPEAKER_00'},
#   {'text': 'nnyo', 'timestamp': (47.46, 47.62), 'speaker': 'SPEAKER_00'},
#   {'text': 'ate', 'timestamp': (47.8, 47.98), 'speaker': 'SPEAKER_00'},
#   {'text': 'era', 'timestamp': (48.06, 48.14), 'speaker': 'SPEAKER_00'},
#   {'text': 'ozitegeerera',
#    'timestamp': (48.32, 48.9),
#    'speaker': 'SPEAKER_00'},
#   {'text': 'ddala', 'timestamp': (48.94, 49.14), 'speaker': 'SPEAKER_00'},
#   {'text': 'bulungi', 'timestamp': (49.2, 49.56), 'speaker': 'SPEAKER_00'},
#   {'text': 'nnyo', 'timestamp': (49.62, 49.8), 'speaker': 'SPEAKER_00'},
#   {'text': 'nkakasa', 'timestamp': (50.94, 51.28), 'speaker': 'SPEAKER_00'},
#   {'text': 'bwe', 'timestamp': (51.34, 51.42), 'speaker': 'SPEAKER_00'},
#   {'text': 'tutandika', 'timestamp': (51.46, 51.96), 'speaker': 'SPEAKER_00'},
#   {'text': 'okwogera', 'timestamp': (52.16, 52.52), 'speaker': 'SPEAKER_00'},
#   {'text': 'ku', 'timestamp': (52.6, 52.66), 'speaker': 'SPEAKER_00'},
#   {'text': 'baana', 'timestamp': (52.68, 52.88), 'speaker': 'SPEAKER_00'},
#   {'text': 'okufuna', 'timestamp': (52.92, 53.16), 'speaker': 'SPEAKER_00'},
#   {'text': 'embuto', 'timestamp': (53.22, 53.48), 'speaker': 'SPEAKER_00'},
#   {'text': 'mu', 'timestamp': (53.92, 54.0), 'speaker': 'SPEAKER_00'},
#   {'text': 'kitundu', 'timestamp': (54.04, 54.46), 'speaker': 'SPEAKER_00'},
#   {'text': 'kyo', 'timestamp': (54.52, 54.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'gwe', 'timestamp': (55.14, 55.26), 'speaker': 'SPEAKER_00'},
#   {'text': 'nga', 'timestamp': (55.5, 55.64), 'speaker': 'SPEAKER_00'},
#   {'text': 'akola', 'timestamp': (55.74, 55.94), 'speaker': 'SPEAKER_00'},
#   {'text': 'ku', 'timestamp': (56.0, 56.06), 'speaker': 'SPEAKER_00'},
#   {'text': 'nsonga', 'timestamp': (56.14, 56.4), 'speaker': 'SPEAKER_00'},
#   {'text': 'zabakyala', 'timestamp': (56.5, 57.12), 'speaker': 'SPEAKER_00'},
#   {'text': 'oteeka', 'timestamp': (57.6, 57.88), 'speaker': 'SPEAKER_00'},
#   {'text': 'okuba', 'timestamp': (58.1, 58.34), 'speaker': 'SPEAKER_00'},
#   {'text': 'nga', 'timestamp': (58.44, 58.54), 'speaker': 'SPEAKER_00'},
#   {'text': 'ozirabye', 'timestamp': (58.98, 59.56), 'speaker': 'SPEAKER_00'},
#   {'text': 'oziwulidde', 'timestamp': (59.86, 60.6), 'speaker': 'SPEAKER_00'},
#   {'text': 'ozikozeeko', 'timestamp': (61.04, 61.96), 'speaker': 'SPEAKER_00'},
#   {'text': 'awuliriza', 'timestamp': (62.78, 63.2), 'speaker': 'SPEAKER_00'},
#   {'text': 'yali', 'timestamp': (63.28, 63.44), 'speaker': 'SPEAKER_00'},
#   {'text': 'agadde', 'timestamp': (63.52, 63.8), 'speaker': 'SPEAKER_00'},
#   {'text': 'okumanyaa', 'timestamp': (63.88, 68.04), 'speaker': 'SPEAKER_01'},
#   {'text': 'nga', 'timestamp': (68.94, 69.06), 'speaker': 'SPEAKER_01'},
#   {'text': 'bwe', 'timestamp': (69.1, 69.2), 'speaker': 'SPEAKER_01'},
#   {'text': 'mbagambye', 'timestamp': (69.24, 69.74), 'speaker': 'SPEAKER_01'},
#   {'text': 'envudde', 'timestamp': (69.8, 70.16), 'speaker': 'SPEAKER_01'},
#   {'text': 'luweero', 'timestamp': (70.28, 70.76), 'speaker': 'SPEAKER_01'},
#   {'text': 'era', 'timestamp': (71.92, 72.08), 'speaker': 'SPEAKER_01'},
#   {'text': 'omulama', 'timestamp': (72.84, 73.16), 'speaker': 'SPEAKER_01'},
#   {'text': 'gwe', 'timestamp': (73.24, 73.34), 'speaker': 'SPEAKER_01'},
#   {'text': 'tulina', 'timestamp': (73.42, 73.74), 'speaker': 'SPEAKER_01'},
#   {'text': 'olwaleeroyinza',
#    'timestamp': (73.82, 78.78),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'okuba', 'timestamp': (78.82, 78.96), 'speaker': 'SPEAKER_00'},
#   {'text': 'sikinnyonnyola',
#    'timestamp': (79.04, 79.66),
#    'speaker': 'SPEAKER_00'},
#   {'text': 'bulungi', 'timestamp': (79.72, 80.02), 'speaker': 'SPEAKER_00'},
#   {'text': 'ngomukugueeza',
#    'timestamp': (80.08, 84.34),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'omwana', 'timestamp': (85.12, 85.56), 'speaker': 'SPEAKER_01'},
#   {'text': 'atanetuuka', 'timestamp': (85.86, 86.9), 'speaker': 'SPEAKER_01'},
#   {'text': 'nolubutoemyaka',
#    'timestamp': (87.58, 90.1),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'gye', 'timestamp': (90.18, 90.26), 'speaker': 'SPEAKER_01'},
#   {'text': 'tusinze', 'timestamp': (90.32, 90.64), 'speaker': 'SPEAKER_01'},
#   {'text': 'okulaba', 'timestamp': (90.72, 91.04), 'speaker': 'SPEAKER_01'},
#   {'text': 'okuviira', 'timestamp': (91.28, 91.62), 'speaker': 'SPEAKER_01'},
#   {'text': 'ddala', 'timestamp': (91.66, 91.84), 'speaker': 'SPEAKER_01'},
#   {'text': 'ku', 'timestamp': (91.92, 92.0), 'speaker': 'SPEAKER_01'},
#   {'text': 'myaka', 'timestamp': (92.08, 92.46), 'speaker': 'SPEAKER_01'},
#   {'text': 'ogambye', 'timestamp': (93.16, 93.48), 'speaker': 'SPEAKER_01'},
#   {'text': 'kumi', 'timestamp': (93.56, 93.7), 'speaker': 'SPEAKER_01'},
#   {'text': 'nesatukmeskdnabakkumi',
#    'timestamp': (93.78, 96.9),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'nogumu', 'timestamp': (97.0, 97.52), 'speaker': 'SPEAKER_01'},
#   {'text': 'kkumi', 'timestamp': (97.56, 97.78), 'speaker': 'SPEAKER_01'},
#   {'text': 'nebiri', 'timestamp': (97.86, 98.3), 'speaker': 'SPEAKER_01'},
#   {'text': 'nga', 'timestamp': (98.72, 98.8), 'speaker': 'SPEAKER_01'},
#   {'text': 'kisinziira', 'timestamp': (98.88, 99.7), 'speaker': 'SPEAKER_01'},
#   {'text': 'ng', 'timestamp': (100.66, 100.72), 'speaker': 'SPEAKER_01'},
#   {'text': 'ol', 'timestamp': (100.8, 100.86), 'speaker': 'SPEAKER_01'},
#   {'text': 'aandise', 'timestamp': (100.94, 101.34), 'speaker': 'SPEAKER_01'},
#   {'text': 'okulaba', 'timestamp': (101.4, 101.72), 'speaker': 'SPEAKER_01'},
#   {'text': 'omusana', 'timestamp': (101.78, 102.24), 'speaker': 'SPEAKER_01'},
#   {'text': 'noze', 'timestamp': (102.86, 103.1), 'speaker': 'SPEAKER_01'},
#   {'text': 'okitegeera',
#    'timestamp': (103.16, 103.74),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'ekyo', 'timestamp': (103.84, 104.02), 'speaker': 'SPEAKER_01'},
#   {'text': 'aba', 'timestamp': (104.5, 104.6), 'speaker': 'SPEAKER_01'},
#   {'text': 'atandise', 'timestamp': (104.66, 104.98), 'speaker': 'SPEAKER_01'},
#   {'text': 'ugenda', 'timestamp': (105.08, 105.3), 'speaker': 'SPEAKER_01'},
#   {'text': 'mu', 'timestamp': (105.36, 105.42), 'speaker': 'SPEAKER_01'},
#   {'text': 'menstral', 'timestamp': (105.46, 105.86), 'speaker': 'SPEAKER_01'},
#   {'text': 'periodsun',
#    'timestamp': (105.92, 108.48),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'kati', 'timestamp': (109.36, 109.52), 'speaker': 'SPEAKER_01'},
#   {'text': 'omwana', 'timestamp': (109.58, 109.84), 'speaker': 'SPEAKER_01'},
#   {'text': 'bwe', 'timestamp': (109.88, 109.96), 'speaker': 'SPEAKER_01'},
#   {'text': 'abatandisi',
#    'timestamp': (110.02, 110.46),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'ogugenda', 'timestamp': (110.5, 110.76), 'speaker': 'SPEAKER_01'},
#   {'text': 'mu', 'timestamp': (110.84, 110.9), 'speaker': 'SPEAKER_01'},
#   {'text': 'nsonga', 'timestamp': (110.98, 111.36), 'speaker': 'SPEAKER_01'},
#   {'text': 'mulimu', 'timestamp': (111.56, 111.96), 'speaker': 'SPEAKER_01'},
#   {'text': 'abagendamu',
#    'timestamp': (112.28, 113.02),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'mangu', 'timestamp': (113.1, 113.5), 'speaker': 'SPEAKER_01'},
#   {'text': 'myaka', 'timestamp': (113.9, 114.22), 'speaker': 'SPEAKER_01'},
#   {'text': 'mwenda', 'timestamp': (114.34, 114.74), 'speaker': 'SPEAKER_01'},
#   {'text': 'myaka', 'timestamp': (114.86, 115.14), 'speaker': 'SPEAKER_01'},
#   {'text': 'kkumi', 'timestamp': (115.24, 115.54), 'speaker': 'SPEAKER_01'},
#   {'text': 'kkumi', 'timestamp': (115.62, 115.82), 'speaker': 'SPEAKER_01'},
#   {'text': 'nagumu', 'timestamp': (115.9, 116.28), 'speaker': 'SPEAKER_01'},
#   {'text': 'ngati', 'timestamp': (116.62, 116.82), 'speaker': 'SPEAKER_00'},
#   {'text': 'weyegata', 'timestamp': (116.88, 117.44), 'speaker': 'SPEAKER_01'},
#   {'text': 'nomulenzi',
#    'timestamp': (117.54, 118.24),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'kuba', 'timestamp': (118.62, 118.74), 'speaker': 'SPEAKER_00'},
#   {'text': 'nomusajja',
#    'timestamp': (118.82, 119.44),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'kiba', 'timestamp': (120.18, 120.36), 'speaker': 'SPEAKER_01'},
#   {'text': 'kitegeeza',
#    'timestamp': (120.42, 120.86),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'abaalina', 'timestamp': (120.94, 121.24), 'speaker': 'SPEAKER_01'},
#   {'text': 'okufuna', 'timestamp': (121.3, 121.6), 'speaker': 'SPEAKER_01'},
#   {'text': 'olubuto', 'timestamp': (121.68, 122.04), 'speaker': 'SPEAKER_01'},
#   {'text': 'kati', 'timestamp': (122.46, 122.74), 'speaker': 'SPEAKER_00'},
#   {'text': 'eieyokuva',
#    'timestamp': (123.58, 125.16),
#    'speaker': 'SPEAKER_01'},
#   {'text': 'kumi', 'timestamp': (125.32, 125.52), 'speaker': 'SPEAKER_01'},
#   {'text': 'nesatu', 'timestamp': (125.6, 126.1), 'speaker': 'SPEAKER_01'},
#   {'text': 'paaka', 'timestamp': (126.18, 126.36), 'speaker': 'SPEAKER_01'},
#   {'text': 'kumi', 'timestamp': (126.44, 126.6), 'speaker': 'SPEAKER_01'},
#   {'text': 'na', 'timestamp': (126.66, 126.72), 'speaker': 'SPEAKER_01'},
#   {'text': 'menda', 'timestamp': (126.8, 127.14), 'speaker': 'SPEAKER_01'},
#   {'text': 'ddala', 'timestamp': (127.66, 127.88), 'speaker': 'SPEAKER_01'},
#   {'text': 'kituufu', 'timestamp': (127.96, 128.58), 'speaker': 'SPEAKER_01'},
#   {'text': 'abaana', 'timestamp': (129.02, 129.48), 'speaker': 'SPEAKER_01'},
#   {'text': 'ensangi', 'timestamp': (129.56, 129.96), 'speaker': 'SPEAKER_01'},
#   {'text': 'zino', 'timestamp': (130.06, 130.26), 'speaker': 'SPEAKER_01'},
#   {'text': 'bazaddenyo',
#    'timestamp': (130.34, 131.02),
#    'speaker': 'SPEAKER_01'}]}

# %%
# todo
# - Measure accuracy
# - M

# %%
# Transcribe Acholi
input_file_path = "/content/acholi_10_d2a408c7-0133-4924-acd0-bb9c568294b7 (1).ogg"
target_language = "ach"
transcription_result = transcribe_audio(input_file_path, target_language, device)
print(transcription_result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-be53e7ea5285> in <cell line: 4>()
#       2 input_file_path = "/content/acholi_10_d2a408c7-0133-4924-acd0-bb9c568294b7 (1).ogg"
#       3 target_language = "ach"
# ----> 4 transcription_result = transcribe_audio(input_file_path, target_language, device)
#       5 print(transcription_result)
#
# <ipython-input-14-688b41bed0ac> in transcribe_audio(input_file, target_lang, device, model_id, chunk_length_s, stride_length_s)
#      38             'start_time': str(start_time),
#      39             'end_time': str(end_time),
# ---> 40             'text': chunk['text']
#      41         })
#      42         start_time = end_time - timedelta(seconds=stride_length_s)  # Overlapping chunks.
#
# TypeError: string indices must be integers

# %%
# Transcribe Ateso
input_file_path = "/content/ateso_1045_18a4b777-ad48-4761-b193-ca0996698ef0.ogg"
target_language = "teo"
transcription_result = transcribe_audio(input_file_path, target_language, device)
print(transcription_result)
# Out:
# {'text': 'abu ngesi oyanga apapulai nu mam adolitos nuda apotu ijaikisi egirio alipan ke na elouni'}

# %%
# Transcribe Ateso
input_file_path = "/content/luganda_1005_7.ogg"
target_language = "lug"
transcription_result = transcribe_audio(input_file_path, target_language, device)
print(transcription_result)
# Out:
# Downloading (…)pter.lug.safetensors:   0%|          | 0.00/8.80M [00:00<?, ?B/s]
# {'text': 'kati kifuuse kya bulijjo bannabyabufuzi okukuubagana ku bifo'}

# %% [markdown]
# ---
